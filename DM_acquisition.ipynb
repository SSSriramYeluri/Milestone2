# %% [markdown]
# 1. Create a project on Google Developers Console
# https://console.developers.google.com
#
# 2. Enable Custom Search API and generate API key
# 3. Create a search engine
# https://cse.google.com/cse/all
#
# 4. Installation
# pip install google-api-python-client

# %%
pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
api_key="AIzaSyBcWSsGyVfBYpGgU7aFRrgoGGp1IrpY7pE"

# %%
from apiclient.discovery import build

# %%
resource = build("customsearch", 'v1', developerKey=api_key).cse()

# %%
images = []

# %%
for i in range(1, 100, 10):
    result = resource.list(q='Bathroom Sinks', cx='009557628044748784875:5lejfe73wrw',
                      searchType='image', start=i).execute()
    images += result['items']

# %%
for item in result['items']:
    print(item['title'], item['link'])
# Out:
# Do presidents sleep in the same room as past presidents? - Quora https://qph.cf2.quoracdn.net/main-qimg-2e4aedf2c26f9852f917f55267df92a6-lq
# How to get help for my cat who is addicted to catnip - Quora https://qph.cf2.quoracdn.net/main-qimg-6dc2ee5037c09c5cad44faa59b477425-lq
# What are the pros and cons of being over six feet tall? - Quora https://qph.cf2.quoracdn.net/main-qimg-d175b90f64d462e37aa5b43ffede715b-lq
# Has anybody ever experimented using PAR cans (stage lights) as an ... https://qph.cf2.quoracdn.net/main-qimg-3d9c3e841ecf8686ee12d60bbdd84689.webp
# Are cats confused/worried by humans bathing/taking showers because ... https://qph.cf2.quoracdn.net/main-qimg-e96b293e6e6a79c62d3be32cff7d51e8-lq
# What is the difference between kitchen faucets and bathroom ... https://qph.cf2.quoracdn.net/main-qimg-40566f069477760f88c1988c1175c3bb-lq
# ...

# %%
images
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Why do the French have bathrooms with just a toilet and no sink ...',
#   'htmlTitle': 'Why do the French have <b>bathrooms</b> with just a <b>toilet</b> and no <b>sink</b> ...',
#   'link': 'https://qph.cf2.quoracdn.net/main-qimg-d8df64a7b3c0fc6340a0fac6f65eb9be-pjlq',
#   'displayLink': 'www.quora.com',
#   'snippet': 'Why do the French have bathrooms with just a toilet and no sink ...',
#   'htmlSnippet': 'Why do the French have <b>bathrooms</b> with just a <b>toilet</b> and no <b>sink</b> ...',
#   'mime': 'image/',
#   'fileFormat': 'image/',
#   'image': {'contextLink': 'https://www.quora.com/Why-do-the-French-have-bathrooms-with-just-a-toilet-and-no-sink',
#    'height': 734,
#    'width': 602,
#    'byteSize': 29827,
#    'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQUPK5JY0z87ociScvUT8gM9T3rLwGVQ0flWczd7CY-EDHaBQKW1P1kCw&s',
#    'thumbnailHeight': 141,
#    'thumbnailWidth': 116}},
# ...
